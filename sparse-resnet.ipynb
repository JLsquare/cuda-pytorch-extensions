# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
from positional_sparse_linear import PositionalSparseLinear, PositionalSparseLinear2d, PositionalSparseLinear3d
from sparse_conv2d import SparseConv2d
from utils import *

device = ("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# !nvidia-smi
# Out:
# Using /home/jl/.cache/torch_extensions/py312_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/jl/.cache/torch_extensions/py312_cu121/positional_sparse_linear_csrc/build.ninja...
# /data/Projets/IA/experimentations/venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module positional_sparse_linear_csrc...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module positional_sparse_linear_csrc...
# ninja: no work to do.
# cuda
# Thu Jun 27 22:22:59 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.52.04              Driver Version: 555.52.04      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   73C    P3             21W /   80W |      51MiB /   6144MiB |     26%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       630      G   /usr/lib/Xorg                                   4MiB |
# |    0   N/A  N/A       778      G   /usr/bin/kwin_wayland                           2MiB |
# +-----------------------------------------------------------------------------------------+

# %%
train_transform = torchvision.transforms.Compose(
    [
        torchvision.transforms.RandomHorizontalFlip(),
        # torchvision.transforms.RandomCrop(32, padding=4),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
        torchvision.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    ]
)

train_set = torchvision.datasets.CIFAR10('DATA_CIFAR/', download=True, train=True, transform=train_transform)
trainLoader = torch.utils.data.DataLoader(train_set, batch_size=128, shuffle=True, num_workers=6)

validation_transform = torchvision.transforms.Compose(
    [
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]
)

validation_set = torchvision.datasets.CIFAR10('DATA_CIFAR/', download=True, train=False, transform=validation_transform)
validationLoader = torch.utils.data.DataLoader(validation_set, batch_size=128, shuffle=True, num_workers=6)

print("Train size : ", len(train_set))
print("validation size : ", len(validation_set))

training_data = enumerate(trainLoader)
batch_idx, (images, labels) = next(training_data)

print(images.shape)
print(labels.shape)

for i in range(0,12):
    plt.subplot(3, 4, i+1)
    plt.imshow((images[i]/ 2 + 0.5).permute(1,2,0).numpy()); plt.axis('off')
    plt.title("label: " + str(labels[i].numpy().squeeze()))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train size :  50000
# validation size :  10000
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.56289303..1.8109179].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.62087727..1.4372498].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6218195..1.8768564].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.627023..1.5651288].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.35071135..1.7967391].
# torch.Size([128, 3, 32, 32])
# torch.Size([128])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6176443..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1160844..1.4372828].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.42793941..1.3723761].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.68653333..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.23544687..1.5247505].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.627162..1.7037984].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.70697975..1.7182883].

# %%
class Block(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(Block, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class SimpleResNet(nn.Module):
    def __init__(self):
        super(SimpleResNet, self).__init__()
        self.in_channels = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        
        self.layer1 = self._make_layer(16, 2, stride=1)
        self.layer2 = self._make_layer(32, 2, stride=2)
        self.layer3 = self._make_layer(64, 2, stride=2)
        
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(64, 10)

    def _make_layer(self, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(Block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

model = SimpleResNet().to(device)
print(trainable_parameters(model))
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# 175258

# %%
train_loss, val_loss, accuracy_total_train, accuracy_total_val, total_time = train_model(
    model,
    trainLoader,
    validationLoader,
    train_set,
    validation_set,
    criterion,
    optimizer,
    device,
    "model/",
    0,
    20
)

plot_loss(train_loss, val_loss)
plot_accuracy(accuracy_total_train, accuracy_total_val)
print("Accuracy of basic linear model: ", test_accuracy(model, validationLoader, validation_set, device))
# Out:
# Epoch: 1/20   Train loss: 1.3803   Valid loss: 1.2635   Train acc: 0.4961   Valid acc: 0.5606   Elapsed time: 24.7036 sec   Time left: 469.3688 sec
# Epoch: 2/20   Train loss: 0.9654   Valid loss: 1.0805   Train acc: 0.6558   Valid acc: 0.6186   Elapsed time: 51.5201 sec   Time left: 482.6954 sec
# Epoch: 3/20   Train loss: 0.8015   Valid loss: 1.0526   Train acc: 0.7180   Valid acc: 0.6254   Elapsed time: 71.9890 sec   Time left: 347.9665 sec
# Epoch: 4/20   Train loss: 0.6999   Valid loss: 0.9828   Train acc: 0.7540   Valid acc: 0.6742   Elapsed time: 87.6626 sec   Time left: 250.7769 sec
# Epoch: 5/20   Train loss: 0.6290   Valid loss: 0.7522   Train acc: 0.7796   Valid acc: 0.7379   Elapsed time: 103.1740 sec   Time left: 232.6685 sec
# Epoch: 6/20   Train loss: 0.5830   Valid loss: 0.7024   Train acc: 0.7973   Valid acc: 0.7566   Elapsed time: 121.4794 sec   Time left: 256.2741 sec
# Epoch: 7/20   Train loss: 0.5358   Valid loss: 0.5980   Train acc: 0.8149   Valid acc: 0.7913   Elapsed time: 146.3631 sec   Time left: 323.4839 sec
# Epoch: 8/20   Train loss: 0.5020   Valid loss: 0.6772   Train acc: 0.8262   Valid acc: 0.7658   Elapsed time: 170.9392 sec   Time left: 294.9111 sec
# Epoch: 9/20   Train loss: 0.4745   Valid loss: 0.6426   Train acc: 0.8355   Valid acc: 0.7758   Elapsed time: 198.9782 sec   Time left: 308.4266 sec
# Epoch: 10/20   Train loss: 0.4458   Valid loss: 0.5451   Train acc: 0.8452   Valid acc: 0.8159   Elapsed time: 225.3238 sec   Time left: 263.4543 sec
# Epoch: 11/20   Train loss: 0.4239   Valid loss: 0.5591   Train acc: 0.8525   Valid acc: 0.8064   Elapsed time: 251.4102 sec   Time left: 234.7761 sec
# Epoch: 12/20   Train loss: 0.4022   Valid loss: 0.5772   Train acc: 0.8598   Valid acc: 0.8035   Elapsed time: 276.0580 sec   Time left: 197.1817 sec
# Epoch: 13/20   Train loss: 0.3837   Valid loss: 0.5832   Train acc: 0.8655   Valid acc: 0.8018   Elapsed time: 299.3993 sec   Time left: 163.3872 sec
# Epoch: 14/20   Train loss: 0.3646   Valid loss: 0.5446   Train acc: 0.8741   Valid acc: 0.8198   Elapsed time: 323.3207 sec   Time left: 143.5274 sec
# Epoch: 15/20   Train loss: 0.3466   Valid loss: 0.6990   Train acc: 0.8782   Valid acc: 0.7684   Elapsed time: 347.4706 sec   Time left: 120.7484 sec
# Epoch: 16/20   Train loss: 0.3379   Valid loss: 0.4838   Train acc: 0.8804   Valid acc: 0.8396   Elapsed time: 368.4582 sec   Time left: 83.9494 sec
# Epoch: 17/20   Train loss: 0.3223   Valid loss: 0.5414   Train acc: 0.8878   Valid acc: 0.8159   Elapsed time: 388.2327 sec   Time left: 59.3228 sec
# Epoch: 18/20   Train loss: 0.3075   Valid loss: 0.5205   Train acc: 0.8930   Valid acc: 0.8323   Elapsed time: 408.6708 sec   Time left: 40.8760 sec
# Epoch: 19/20   Train loss: 0.2985   Valid loss: 0.5303   Train acc: 0.8950   Valid acc: 0.8258   Elapsed time: 428.5008 sec   Time left: 19.8299 sec
# Epoch: 20/20   Train loss: 0.2815   Valid loss: 0.5156   Train acc: 0.9020   Valid acc: 0.8303   Elapsed time: 447.6501 sec   Time left: 0.0000 sec
# Accuracy of basic linear model:  0.8303

# %%
class SparseBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(SparseBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class SparseResNet(nn.Module):
    def __init__(self):
        super(SparseResNet, self).__init__()
        self.in_channels = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        
        self.layer1 = self._make_layer(16, 2, stride=1)
        self.layer2 = self._make_layer(32, 2, stride=2)
        self.layer3 = self._make_layer(64, 2, stride=2)
        
        self.fc1 = PositionalSparseLinear3d(64, 8, 8, 16, 8, 8, 16)
        self.fc2 = PositionalSparseLinear3d(16, 8, 8, 8, 4, 4, 16)
        self.fc3 = PositionalSparseLinear(8 * 4 * 4, 10, 32, True)

    def _make_layer(self, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(Block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.fc1(out)
        out = self.fc2(out)
        out = out.view(out.size(0), -1)
        out = self.fc3(out)
        return out
    
model = SparseLinearResNet().to(device)
print(trainable_parameters(model))
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# 193360

# %%
train_loss, val_loss, accuracy_total_train, accuracy_total_val, total_time = train_model(
    model,
    trainLoader,
    validationLoader,
    train_set,
    validation_set,
    criterion,
    optimizer,
    device,
    "model/",
    0,
    20
)

plot_loss(train_loss, val_loss)
plot_accuracy(accuracy_total_train, accuracy_total_val)
print("Accuracy of basic linear model: ", test_accuracy(model, validationLoader, validation_set, device))
# Out:
# Epoch: 1/20   Train loss: 1.3871   Valid loss: 1.2440   Train acc: 0.4971   Valid acc: 0.5580   Elapsed time: 17.3780 sec   Time left: 330.1819 sec
# Epoch: 2/20   Train loss: 0.9289   Valid loss: 0.8897   Train acc: 0.6715   Valid acc: 0.6893   Elapsed time: 36.5380 sec   Time left: 344.8778 sec
# Epoch: 3/20   Train loss: 0.7485   Valid loss: 0.7519   Train acc: 0.7384   Valid acc: 0.7398   Elapsed time: 56.0902 sec   Time left: 332.3858 sec
# Epoch: 4/20   Train loss: 0.6484   Valid loss: 0.7814   Train acc: 0.7722   Valid acc: 0.7288   Elapsed time: 77.1489 sec   Time left: 336.9362 sec
# Epoch: 5/20   Train loss: 0.5807   Valid loss: 0.7124   Train acc: 0.7972   Valid acc: 0.7545   Elapsed time: 101.4691 sec   Time left: 364.7999 sec
# Epoch: 6/20   Train loss: 0.5267   Valid loss: 0.6393   Train acc: 0.8158   Valid acc: 0.7855   Elapsed time: 129.4610 sec   Time left: 391.8851 sec
# Epoch: 7/20   Train loss: 0.4825   Valid loss: 0.6176   Train acc: 0.8316   Valid acc: 0.7894   Elapsed time: 154.7897 sec   Time left: 329.2712 sec
# Epoch: 8/20   Train loss: 0.4428   Valid loss: 0.6168   Train acc: 0.8460   Valid acc: 0.7906   Elapsed time: 177.8655 sec   Time left: 276.9081 sec
# Epoch: 9/20   Train loss: 0.4074   Valid loss: 0.5846   Train acc: 0.8585   Valid acc: 0.8024   Elapsed time: 201.3010 sec   Time left: 257.7888 sec
# Epoch: 10/20   Train loss: 0.3847   Valid loss: 0.5940   Train acc: 0.8668   Valid acc: 0.8053   Elapsed time: 224.1046 sec   Time left: 228.0345 sec
# Epoch: 11/20   Train loss: 0.3534   Valid loss: 0.6136   Train acc: 0.8771   Valid acc: 0.7970   Elapsed time: 247.6168 sec   Time left: 211.6079 sec
# Epoch: 12/20   Train loss: 0.3338   Valid loss: 0.5824   Train acc: 0.8822   Valid acc: 0.8015   Elapsed time: 270.5944 sec   Time left: 183.8195 sec
# Epoch: 13/20   Train loss: 0.3190   Valid loss: 0.5808   Train acc: 0.8872   Valid acc: 0.8083   Elapsed time: 294.7474 sec   Time left: 169.0701 sec
# Epoch: 14/20   Train loss: 0.2934   Valid loss: 0.6120   Train acc: 0.8975   Valid acc: 0.8020   Elapsed time: 315.7029 sec   Time left: 125.7320 sec
# Epoch: 15/20   Train loss: 0.2780   Valid loss: 0.6106   Train acc: 0.9033   Valid acc: 0.8119   Elapsed time: 335.1494 sec   Time left: 97.2317 sec
# Epoch: 16/20   Train loss: 0.2532   Valid loss: 0.6460   Train acc: 0.9100   Valid acc: 0.8071   Elapsed time: 354.5057 sec   Time left: 77.4247 sec
# Epoch: 17/20   Train loss: 0.2391   Valid loss: 0.5935   Train acc: 0.9171   Valid acc: 0.8160   Elapsed time: 374.0750 sec   Time left: 58.7077 sec
# Epoch: 18/20   Train loss: 0.2257   Valid loss: 0.6510   Train acc: 0.9207   Valid acc: 0.8089   Elapsed time: 393.6977 sec   Time left: 39.2450 sec
# Epoch: 19/20   Train loss: 0.2203   Valid loss: 0.6185   Train acc: 0.9230   Valid acc: 0.8147   Elapsed time: 414.0650 sec   Time left: 20.3671 sec
# Epoch: 20/20   Train loss: 0.1996   Valid loss: 0.6483   Train acc: 0.9300   Valid acc: 0.8126   Elapsed time: 435.2857 sec   Time left: 0.0000 sec
# Accuracy of basic linear model:  0.8126
